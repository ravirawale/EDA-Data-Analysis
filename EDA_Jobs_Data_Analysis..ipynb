# %% [markdown]
# # Importing Rquried Lab

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # Creating Data Set

# %%
df=pd.read_csv("jobs_in_data.csv",encoding='unicode_escape')
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %% [markdown]
# # Getting Summary Of Dataset

# %%
--> Columns
--> Shape
--> dtypes
--> info
--> describe Numerical Columns
--> describe of all columns
--> null Values
--> Duplicate
--> index

# %%
#Checking Columns of Datasets
df.columns

for i in df.columns:
    print(i)
# Out:
# work_year
# job_title
# job_category
# salary_currency
# salary
# salary_in_usd
# employee_residence
# experience_level
# employment_type
# work_setting
# company_location
# company_size

# %%
#Checking Shape Of DataSet
df.shape
        #Here,9355 Rows and 12 is Columns
# Out:
# (9355, 12)

# %%
#Checking Columns Data Types
df.dtypes
# Out:
# work_year                 int64
# job_title                object
# job_category             object
# salary_currency          object
# salary                    int64
# salary_in_usd             int64
# employee_residence       object
# experience_level         object
# employment_type          object
# work_setting             object
# company_location         object
# company_size             object
# Total_Year_Experience     int64
# dtype: object

# %%
#Getting Information of All Data Set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   work_year              9355 non-null   int64
#  1   job_title              9355 non-null   object
#  2   job_category           9355 non-null   object
#  3   salary_currency        9355 non-null   object
#  4   salary                 9355 non-null   int64
#  5   salary_in_usd          9355 non-null   int64
#  6   employee_residence     9355 non-null   object
#  7   experience_level       9355 non-null   object
#  8   employment_type        9355 non-null   object
#  9   work_setting           9355 non-null   object
#  10  company_location       9355 non-null   object
#  11  company_size           9355 non-null   object
#  12  Total_Year_Experience  9355 non-null   int64
# dtypes: int64(4), object(9)
# memory usage: 950.2+ KB

# %%
#Getting Numerical columns data Description Mean Mode meadian
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
#Getting All Columns all descriptions
df.describe(include='all')
# Out:
#           work_year      job_title               job_category salary_currency  \
# count   9355.000000           9355                       9355            9355
# unique          NaN            125                         10              11
# top             NaN  Data Engineer  Data Science and Research             USD
# freq            NaN           2195                       3014            8591
# mean    2022.760449            NaN                        NaN             NaN
# std        0.519470            NaN                        NaN             NaN
# min     2020.000000            NaN                        NaN             NaN
# 25%     2023.000000            NaN                        NaN             NaN
# 50%     2023.000000            NaN                        NaN             NaN
# 75%     2023.000000            NaN                        NaN             NaN
# max     2023.000000            NaN                        NaN             NaN
#
# ...

# %%
#Checking Null Values In form Of Boolean Ex.True/False
df.isnull()
# Out:
#       work_year  job_title  job_category  salary_currency  salary  \
# 0         False      False         False            False   False
# 1         False      False         False            False   False
# 2         False      False         False            False   False
# 3         False      False         False            False   False
# 4         False      False         False            False   False
# ...         ...        ...           ...              ...     ...
# 9350      False      False         False            False   False
# 9351      False      False         False            False   False
# 9352      False      False         False            False   False
# 9353      False      False         False            False   False
# 9354      False      False         False            False   False
#
#       salary_in_usd  employee_residence  experience_level  employment_type  \
# 0             False               False             False            False
# ...

# %%
#Getting Null Values in total Form with sum Function with null
df.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#Checking Dupliactes in the Bollean values
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9350    False
# 9351    False
# 9352    False
# 9353    False
# 9354    False
# Length: 9355, dtype: bool

# %%
#Checking Du;icated in total forms with Sum Function with Dupliacted
df.duplicated().sum()

#Here,Total 4014 Duplicated Values in total Datas set
# Out:
# 4014

# %%
#Checking Index of Data Set
df.index
# Out:
# RangeIndex(start=0, stop=9355, step=1)

# %% [markdown]
# # Dropping Dulpicate

# %%
#Droppinf Duplicated Values from Dataset
df.drop_duplicates(inplace=True)

# %%
df.shape
#Now Here, 5341 Rows and 12 Columns Remains after Dropping Duplicated Values
# Out:
# (5341, 13)

# %% [markdown]
# # Adding New Column in Data Set as Total Year of Experience

# %%
current_year=datetime.now().year
df['Total_Year_Experience']= current_year - df['work_year']
df.columns
df.shape

#Here New Columns is added
# Out:
# (5341, 13)

# %% [markdown]
# # Outlier Detection in salary column

# %%
df['salary'].plot(kind='box')

#Here Between 300000 - 400000 are Outliers
# Out:
# <Axes: >

# %% [markdown]
# # Removing outlier from salary columns

# %%
def f_per(data, va):
    ub = np.percentile(data[va], 99)
    lb = np.percentile(data[va], 1)
    return lb, ub
  
def z_score(data, va):
    ub = data[va].mean() + 2.5 * data[va].std()
    lb = data[va].mean() - 2.5 * data[va].std()
    return lb, ub
  
def iqr(data, va):
    Q1 = np.percentile(data[va], 25)
    Q3 = np.percentile(data[va], 75)
    iqr_val = Q3 - Q1
    ub = Q3 + 1.5 * iqr_val
    lb = Q1 - 1.5 * iqr_val
    return lb, ub


print("salary percentile :", f_per(df, 'salary'))
print("salary_in_usd percentile :", f_per(df, 'salary_in_usd'))
print("salary IQR :", iqr(df, 'salary'))
print("salary_in_usd IQR :", iqr(df, 'salary_in_usd'))
print("salary z_score :", z_score(df, 'salary'))
print("salary_in_usd z_score :", z_score(df, 'salary_in_usd'))
print(df['salary'].min(),df['salary_in_usd'].min())
print(df['salary'].max(),df['salary_in_usd'].max())
# Out:
# salary percentile : (35000.0, 328061.1799999999)
# salary_in_usd percentile : (36000.0, 328905.99999999907)
# salary IQR : (-17500.0, 309700.0)
# salary_in_usd IQR : (-15834.5, 308257.5)
# salary z_score : (-9094.107174903183, 308950.0697617552)
# salary_in_usd z_score : (-7643.934497219714, 308242.92562495894)
# 14000 15000
# 450000 450000

# %%
df['salary']=np.clip(df['salary'],a_min=iqr(df, 'salary')[0],a_max=iqr(df, 'salary')[1])

# %%
df['salary'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Descriptive Analysis:

# %%
#Q1. What is the distribution of work years among employees?

#Boxplot
df['work_year'].plot(kind='box')
plt.title("distribution of work years among employees".upper())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#kdeplot
sns.kdeplot(df['work_year'])
plt.title('Distribution of Work Years Among Employees'.upper())
plt.xlabel('Work Years')
plt.ylabel('Density')
plt.show()

# %%
#Histplot
sns.histplot(df['work_year'],kde=True)
plt.title('Distribution of work year amoung employees'.upper())
plt.xlabel('Work Year')
# Out:
# Text(0.5, 0, 'Work Year')

# %%
#Q2. What are the most common job titles and job categories in the dataset?

#Job Category
ax=sns.countplot(x=df['job_category'],order=df['job_category'].value_counts().index)
plt.title('Most common job category'.upper())
plt.xlabel('Job Category')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Now Job Title
plt.figure(figsize=(5,20))
sns.countplot(y=df['job_title'],order=df['job_title'].value_counts().index)
plt.title('most common job titles'.upper())
plt.xlabel('Count')
plt.ylabel("Job Titles")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Q3. How is salary distributed across different job categories?


plt.figure(figsize=(10,5))
sns.barplot(x=df['job_category'],y=df['salary'],order=df['job_category'].value_counts().index)
plt.title('Salary distribution by category'.capitalize())
plt.xlabel('Job Category')
plt.ylabel('Salary')
plt.xticks(rotation=45,ha='right')
plt.show


#Here we can also use boxplot,violinplt
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Salary Analysis:

# %%
#Q1.  What is the average salary for different job titles or categories?

# %%
average_salary_by_job = df.groupby('job_title')['salary'].mean().reset_index()

# Sort the data by average salary
average_salary_by_job = average_salary_by_job.sort_values(by='salary', ascending=False)

# Create a horizontal bar plot
plt.figure(figsize=(10, 20))
sns.barplot(x='salary', y='job_title', data=average_salary_by_job, palette='viridis')
plt.title('Average Salary by Job Title')
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.show()

# %%
#Q2. How does salary vary based on experience level or employment type?

for i in df.columns:
    print(i)
# Out:
# work_year
# job_title
# job_category
# salary_currency
# salary
# salary_in_usd
# employee_residence
# experience_level
# employment_type
# work_setting
# company_location
# company_size

# %%
#Q2. How does salary vary based on experience level or employment type?

plt.figure(figsize=(10,5))
ax=sns.barplot(x=df['experience_level'],y=df['salary'],order=df['experience_level'].value_counts().index)
plt.title("salary based on experience level".capitalize())
plt.xlabel('Experience Level'.upper())
plt.ylabel('Salary')
plt.xticks(rotation=(45))
plt.show

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Q3. Can we identify any outliers in the salary data?
df['salary'].plot(kind=('box'))

#df['salary'].plot(kind='box')

#Here Between 300000 - 400000 are Outliers
# Out:
# <Axes: >

# %% [markdown]
# # Geographical Analysis:

# %%
#Q1 What are the primary company locations in the dataset?

company_location_counts=df['company_location'].value_counts()
company_location_counts
plt.figure(figsize=(12,6))
company_location_counts.plot(kind='bar')
plt.title('Primary Company Locations in Dataset')
plt.xlabel("Compay Locations")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Q2. How does salary vary across different company locations?
plt.figure(figsize=(12,6))
sns.barplot(x=df['company_location'],y=df['salary'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x=df['company_location'],y=df['salary'])
plt.xticks(rotation=(90))
plt.xlabel('Company Location')
plt.ylabel('Salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Q3. Is there any correlation between company size and location?
plt.figure(figsize=(12,6))
sns.scatterplot(y=df['company_size'],x=df['company_location'])
plt.title('Correlation Between Company size and company Location'.capitalize())
plt.xlabel('Company Location')
plt.ylabel('Company Size')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Experience Level Analysis:

# %%
#Q1. How is work experience distributed among employees?

ax=sns.histplot(x=df['experience_level'],kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Work experience Distribution'.upper())
# Out:
# Text(0.5, 1.0, 'WORK EXPERIENCE DISTRIBUTION')

# %%
#Q2. Does experience level impact salary or job title?

sns.kdeplot([df['experience_level'],df['job_title'],df['salary']])
# Out:
# <Axes: ylabel='Density'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))


plt.hist([df['experience_level'], df['job_title'], df['salary']], bins=20, alpha=0.7, label=['Experience', 'Job Title', 'Salary'])

plt.title('Histogram of Three Columns')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.xticks(rotation=(90))

plt.show()

# %% [markdown]
# # Employment Type and Work Setting:

# %%
#Q1. What are the predominant employment types in the dataset?
for i in df.columns:
    print(i)
# Out:
# work_year
# job_title
# job_category
# salary_currency
# salary
# salary_in_usd
# employee_residence
# experience_level
# employment_type
# work_setting
# company_location
# company_size

# %%
ax=sns.countplot(x=df['employment_type'])
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Q2. How does work setting (e.g., remote vs. office) relate to job titles or salaries?

plt.figure(figsize=(20,6))
ax=sns.histplot([df['work_setting'],df['salary'],df['job_title']],kde=True)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.barplot(x=df['work_setting'],y=df['salary'])
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# # Company Size Analysis:

# %%
#Q1. What is the distribution of company sizes?
ax=sns.histplot(df['company_size'])
for bar in ax.containers:
    ax.bar_label(bar)

# %%
#Q2. Are there patterns or trends related to company size and job categories?
for i in df.columns:
    print(i)
# Out:
# work_year
# job_title
# job_category
# salary_currency
# salary
# salary_in_usd
# employee_residence
# experience_level
# employment_type
# work_setting
# company_location
# company_size

# %%
plt.figure(figsize=(12,6))
ax=sns.countplot(x='company_size',hue='job_category',data=df)
plt.title('Job Categories Distribution Across Company Sizes')
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# # Residence and Mobility:

# %%
#Q1. Where do employees commonly reside?
plt.figure(figsize=(12,6))
sns.histplot(df['employee_residence'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
